# %% [markdown]
# # RIGID

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
from matplotlib.gridspec import GridSpec
import pandas as pd
import time
import numpy as np
df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/rigid/kpx_0.0017*13/trial1.csv")
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/rigid/kpx_0.0017*13/trial2.csv")
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/rigid/kpx_0.0017*2/trial3.csv")
df4 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/rigid/kpx_0.0017*2/trial4.csv")
df5 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/rigid/kpx_0.0017*7/trial5.csv")
df6 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/rigid/kpx_0.0017*7/trial6.csv")

# %% [markdown]
# ## Trial 1 Vel=33mm/sec

# %%
fig, (ax1_rig_33, ax2_rig_33) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
rcParams['mathtext.rm'] = 'Arial'
#ax1.set_title("(RIGID OBJ) FORCE stage | Vel=33mm/sec")
time_rf_33= np.linspace(0, 28.0, 14000)
hall_real_rf_33 = -df1["real_hall"]
hall_des_rf_33 = df1["desired_hall"]
ax1_rig_33.plot(time_rf_33[0:8500], hall_real_rf_33[2500:11000], c = "r")
ax1_rig_33.plot(time_rf_33[0:8500], hall_des_rf_33[2500:11000],linestyle='dashed', c="black")
major_ticksx1 = np.arange(0,20,2)
major_ticksy1 = np.arange(0, 2.25, 0.5)
ax1_rig_33.set_xticks(major_ticksx1)
ax1_rig_33.set_yticks(major_ticksy1)
ax1_rig_33.tick_params(axis='both', which='major', labelsize=25)
ax1_rig_33.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1_rig_33.set_ylabel('$\mathrm{d, mm}$',fontsize = 25, weight="bold")

#ax2.set_title("(RIGID OBJ) SENSING stage | Vel=33mm/sec")
time_rs_33= np.linspace(0, 44.0, 22000)
hall_real_rs_33 = -df2["real_hall"]
hall_des_rs_33 = df2["desired_hall"]
ax2_rig_33.plot(time_rs_33[0:8500], hall_real_rs_33[6500:15000], c = "r")
ax2_rig_33.plot(time_rs_33[0:8500], hall_des_rs_33[6500:15000],linestyle='dashed', c = "black")
major_ticksx2 = np.arange(0,20,2)
major_ticksy2 = np.arange(3.0, 6.25, 0.5)
ax2_rig_33.set_xticks(major_ticksx2)
ax2_rig_33.set_yticks(major_ticksy2)
ax2_rig_33.tick_params(axis='both', which='major', labelsize=25)
ax2_rig_33.grid(linestyle='dashed')
ax2_rig_33.set_xlabel('$\mathrm{time, s}$',fontsize = 25, weight="bold")
ax2_rig_33.set_ylabel('$\mathrm{d, mm}$',fontsize = 25,weight="bold")
#plt.savefig('rigid_33.eps', format='eps')
# Out:
# Text(0,0.5,'$\\mathrm{d, mm}$')

# %% [markdown]
# ## RMSE Vel=33mm/sec | RIGID OBJECT | FORCE STATE

# %%
#import necessary libraries
from sklearn.metrics import mean_squared_error
from math import sqrt

plt.figure(figsize=(12,8), dpi= 100) 
error1_rigid = hall_des_rf_33[2500:11000] - hall_real_rf_33[2500:11000]
error2_rigid = hall_des_rs_33[6500:15000] - hall_real_rs_33[6500:15000]
plt.boxplot([error1_rigid, error2_rigid],showfliers=False) 

rmse_rigid_f = (np.diff(np.array(error1_rigid)) ** 2).mean() ** .5
rmse_rigid_s = (np.diff(np.array(error2_rigid)) ** 2).mean() ** .5
plt.show()
rmse_rf_33 = mean_squared_error(hall_des_rf_33[2500:11000], hall_real_rf_33[2500:11000])
rmse_rs_33 = mean_squared_error(hall_des_rs_33[6500:15000], hall_real_rs_33[6500:15000])
print(rmse_rf_33)
print(rmse_rs_33)
# Out:
# 0.09297919308603544
# 0.263707768827048

# %% [markdown]
# ## Trial 2 Vel=5mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
#ax1.set_title("(RIGID OBJ) FORCE stage | Vel=5mm/sec")
time_rf_5 = np.linspace(0, 40.0, 20000)
hall_real_rf_5 = -df3["real_hall"]
hall_des_rf_5 = df3["desired_hall"]
ax1.plot(time_rf_5[0:8500], hall_real_rf_5[8500:17000], c="red")
ax1.plot(time_rf_5[0:8500], hall_des_rf_5[8500:17000],linestyle='dashed', c="black")
major_ticksx3 = np.arange(0,20,2)
major_ticksy3 = np.arange(0, 2.25, 0.5)
ax1.set_xticks(major_ticksx3)
ax1.set_yticks(major_ticksy3)
ax1.tick_params(axis='both', which='major', labelsize=25)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)

#ax2.set_title("(RIGID OBJ) SENSING stage | Vel=5mm/sec")
time_rs_5= np.linspace(0, 52.0, 26000)
hall_real_rs_5 = -df4["real_hall"]
hall_des_rs_5 = df4["desired_hall"]
ax2.plot(time_rs_5[0:8500], hall_real_rs_5[8500:17000], c="red")
ax2.plot(time_rs_5[0:8500], hall_des_rs_5[8500:17000],linestyle='dashed', c="black")
major_ticksx2 = np.arange(0,20,2)
major_ticksy2 = np.arange(3.0, 5.00, 0.5)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=25)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 25)
ax2.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)
#plt.savefig('rigid_5.eps', format='eps')
# Out:
# Text(0,0.5,'$\\mathrm{d, mm}$')

# %% [markdown]
# ## RMSE Vel=5mm/sec | RIGID OBJECT | FORCE STATE

# %%
#import necessary libraries
from sklearn.metrics import mean_squared_error
from math import sqrt
plt.figure(figsize=(12,8), dpi= 100) 
error3_rigid = hall_des_rf_5[8500:17000] - hall_real_rf_5[8500:17000]
error4_rigid = hall_des_rs_5[8500:17000] - hall_real_rs_5[8500:17000]
rmse_rf_5 = mean_squared_error(hall_des_rf_5[8500:17000], hall_real_rf_5[8500:17000])
rmse_rs_5 = mean_squared_error(hall_des_rs_5[8500:17000], hall_real_rs_5[8500:17000])
print(rmse_rf_5)
print(rmse_rs_5)
plt.boxplot([error3_rigid, error4_rigid],showfliers=False) 
plt.show()
# Out:
# 0.3539553650802928
# 0.2989924070942038

# %% [markdown]
# ## Trial 3 Vel=18mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
#ax1.set_title("(RIGID OBJ) FORCE stage | Vel=18mm/sec")
time_rf_18= np.linspace(0, 40.0, 20000)
hall_real_rf_18 = -df5["real_hall"]
hall_des_rf_18 = df5["desired_hall"]
ax1.plot(time_rf_18[0:8500], hall_real_rf_18[8500:17000],c="red")
ax1.plot(time_rf_18[0:8500], hall_des_rf_18[8500:17000],linestyle='dashed', c="black")
major_ticksx5 = np.arange(0,20,2)
major_ticksy5 = np.arange(0, 2.25, 0.5)
ax1.set_xticks(major_ticksx5)
ax1.set_yticks(major_ticksy5)
ax1.tick_params(axis='both', which='major', labelsize=25)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)

#ax2.set_title("(RIGID OBJ) SENSING stage | Vel=18mm/sec")
time_rs_18= np.linspace(0, 60.0, 30000)
hall_real_rs_18 = -df6["real_hall"]
hall_des_rs_18 = df6["desired_hall"]
ax2.plot(time_rs_18[0:8500], hall_real_rs_18[8500:17000],c="red")
ax2.plot(time_rs_18[0:8500], hall_des_rs_18[8500:17000],linestyle='dashed', c="black")
major_ticksx6 = np.arange(0,20,2)
major_ticksy6 = np.arange(3.0, 5.00, 0.5)
ax2.set_xticks(major_ticksx6)
ax2.set_yticks(major_ticksy6)
ax2.tick_params(axis='both', which='major', labelsize=25)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 25)
ax2.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)
#plt.savefig('rigid_18.eps', format='eps')
# Out:
# Text(0,0.5,'$\\mathrm{d, mm}$')

# %% [markdown]
# ## RMSE Vel=18mm/sec | RIGID OBJECT | FORCE STATE

# %%
#import necessary libraries
from sklearn.metrics import mean_squared_error
from math import sqrt
plt.figure(figsize=(12,8), dpi= 100) 
error5_rigid = hall_des_rf_18[8500:17000] - hall_real_rf_18[8500:17000]
error6_rigid = hall_des_rs_18[8500:17000] - hall_real_rs_18[8500:17000]

rmse_rf_18 = mean_squared_error(hall_des_rf_18[8500:17000], hall_real_rf_18[8500:17000])
rmse_rs_18 = mean_squared_error(hall_des_rs_18[8500:17000], hall_real_rs_18[8500:17000])
print(rmse_rf_18)
print(rmse_rs_18)

plt.boxplot([error5_rigid, error6_rigid],showfliers=False) 
plt.xticks([1, 2], ['Force', 'Sensing'])
plt.show()
# Out:
# 0.1725403842358302
# 0.30422439841821386

# %% [markdown]
# # SEMI-SOFT

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import time
import numpy as np
df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/semi-soft/kpx_0.0017*13/trial1.csv")
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/semi-soft/kpx_0.0017*13/trial2.csv")
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/semi-soft/kpx_0.0017*2/trial1.csv")
df4 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/semi-soft/kpx_0.0017*2/trial2.csv")
df5 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/semi-soft/kpx_0.0017*7/trial1.csv")
df6 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/semi-soft/kpx_0.0017*7/trial2.csv")

# %% [markdown]
# ## Trial 1 Vel=33mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
ax1.set_title("(SEMI-SOFT OBJ) FORCE stage | Vel=33mm/sec")
time1= np.linspace(0, 60.0, 30000)
hall_real_1 = -df1["real_hall"]
hall_des_1 = df1["desired_hall"]
ax1.plot(time1[0:8500], hall_real_1[2500:11000])
ax1.plot(time1[0:8500], hall_des_1[2500:11000])
major_ticksx1 = np.arange(0,20,1)
major_ticksy1 = np.arange(0, 3.75, 0.25)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Hall Disp, mm',fontsize = 15)

ax2.set_title("(SEMI-SOFT OBJ) SENSING stage | Vel=33mm/sec")
time2= np.linspace(0, 44.0, 22000)
hall_real_2 = -df2["real_hall"]
hall_des_2 = df2["desired_hall"]
ax2.plot(time2[0:8500], hall_real_2[6500:15000])
ax2.plot(time2[0:8500], hall_des_2[6500:15000])
major_ticksx2 = np.arange(0,20,1)
major_ticksy2 = np.arange(3.0, 6.25, 0.25)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall Disp, mm',fontsize = 15)
# Out:
# Text(0,0.5,'Hall Disp, mm')

# %% [markdown]
# ## Trial 2 Vel=5mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
ax1.set_title("(SEMI-SOFT OBJ) FORCE stage | Vel=5mm/sec")
time3= np.linspace(0, 40.0, 20000)
hall_real_3 = -df3["real_hall"]
hall_des_3 = df3["desired_hall"]
ax1.plot(time3[0:8500], hall_real_3[8500:17000])
ax1.plot(time3[0:8500], hall_des_3[8500:17000])
major_ticksx3 = np.arange(0,20,1)
major_ticksy3 = np.arange(0, 2.25, 0.25)
ax1.set_xticks(major_ticksx3)
ax1.set_yticks(major_ticksy3)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Hall Disp, mm',fontsize = 15)

ax2.set_title("(SEMI-SOFT OBJ) SENSING stage | Vel=5mm/sec")
time4= np.linspace(0, 52.0, 26000)
hall_real_4 = -df4["real_hall"]
hall_des_4 = df4["desired_hall"]
ax2.plot(time4[0:8500], hall_real_4[8500:17000])
ax2.plot(time4[0:8500], hall_des_4[8500:17000])
major_ticksx2 = np.arange(0,20,1)
major_ticksy2 = np.arange(3.0, 5.00, 0.25)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall Disp, mm',fontsize = 15)
# Out:
# Text(0,0.5,'Hall Disp, mm')

# %% [markdown]
# ## Trial 3 Vel=18mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
ax1.set_title("(SEMI-SOFT OBJ)FORCE stage | Vel=18mm/sec")
time5= np.linspace(0, 40.0, 20000)
hall_real_5 = -df5["real_hall"]
hall_des_5 = df5["desired_hall"]
ax1.plot(time5[0:8500], hall_real_5[8500:17000])
ax1.plot(time5[0:8500], hall_des_5[8500:17000])
major_ticksx5 = np.arange(0,20,1)
major_ticksy5 = np.arange(0, 2.25, 0.25)
ax1.set_xticks(major_ticksx5)
ax1.set_yticks(major_ticksy5)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Hall Disp, mm',fontsize = 15)

ax2.set_title("(SEMI-SOFT OBJ) SENSING stage | Vel=18mm/sec")
time6= np.linspace(0, 60.0, 30000)
hall_real_6 = -df6["real_hall"]
hall_des_6 = df6["desired_hall"]
ax2.plot(time6[0:8500], hall_real_6[8500:17000])
ax2.plot(time6[0:8500], hall_des_6[8500:17000])
major_ticksx6 = np.arange(0,20,1)
major_ticksy6 = np.arange(3.0, 5.00, 0.25)
ax2.set_xticks(major_ticksx6)
ax2.set_yticks(major_ticksy6)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall Disp, mm',fontsize = 15)
# Out:
# Text(0,0.5,'Hall Disp, mm')

# %% [markdown]
# # SOFT

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import time
import numpy as np
df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/soft/kpx_0.0017*13/trial1.csv")
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/soft/kpx_0.0017*13/trial2.csv")
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/soft/kpx_0.0017*2/trial1.csv")
df4 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/soft/kpx_0.0017*2/trial2.csv")
df5 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/soft/kpx_0.0017*7/trial1.csv")
df6 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/soft_rigid/soft/kpx_0.0017*7/trial2.csv")

# %% [markdown]
# ## Trial 1 Vel=33mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
#ax1.set_title("(SOFT OBJ) FORCE stage | Vel=33mm/sec")
time_sf_33= np.linspace(0, 60.0, 30000)
hall_real_sf_33 = -df1["real_hall"]
hall_des_sf_33 = df1["desired_hall"]
ax1.plot(time_sf_33[0:8500], hall_real_sf_33[2500:11000], c="red")
ax1.plot(time_sf_33[0:8500], hall_des_sf_33[2500:11000],linestyle='dashed', c="black")
major_ticksx1 = np.arange(0,20,2)
major_ticksy1 = np.arange(0, 5.25, 1)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=25)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)

#ax2.set_title("(SOFT OBJ) SENSING stage | Vel=33mm/sec")
time_ss_33= np.linspace(0, 44.0, 22000)
hall_real_ss_33 = -df2["real_hall"]
hall_des_ss_33 = df2["desired_hall"]
ax2.plot(time_ss_33[0:8500], hall_real_ss_33[4500:13000], c="red")
ax2.plot(time_ss_33[0:8500], hall_des_ss_33[4500:13000],linestyle='dashed', c="black")
major_ticksx2 = np.arange(0,20,2)
major_ticksy2 = np.arange(3.0, 6.25, 0.5)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=25)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 25)
ax2.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)
#plt.savefig('soft_33.eps', format='eps')
# Out:
# Text(0,0.5,'$\\mathrm{d, mm}$')

# %% [markdown]
# ## RMSE Vel=33mm/sec | SOFT OBJECT | FORCE STATE

# %%
#import necessary libraries
from sklearn.metrics import mean_squared_error
from math import sqrt
plt.figure(figsize=(12,8), dpi= 100) 
error1_soft = hall_des_sf_33[2500:11000] - hall_real_sf_33[2500:11000]
error2_soft = hall_des_ss_33[4500:13000] - hall_real_ss_33[4500:13000]

rmse_sf_33 = mean_squared_error(hall_des_sf_33[2500:11000], hall_real_sf_33[2500:11000])
rmse_ss_33 = mean_squared_error(hall_des_ss_33[4500:13000], hall_real_ss_33[4500:13000])
print(rmse_sf_33)
print(rmse_ss_33)

plt.boxplot([error1_soft, error2_soft],showfliers=False) 
plt.xticks([1, 2], ['Force', 'Sensing'])


plt.show()
# Out:
# 1.7254065185155196
# 0.24342941191496148

# %% [markdown]
# ## Trial 2 Vel=5mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
#ax1.set_title("(SOFT OBJ) FORCE stage | Vel=5mm/sec")
time_sf_5= np.linspace(0, 40.0, 20000)
hall_real_sf_5 = -df3["real_hall"]
hall_des_sf_5 = df3["desired_hall"]
ax1.plot(time_sf_5[0:8500], hall_real_sf_5[12500:21000], c="red")
ax1.plot(time_sf_5[0:8500], hall_des_sf_5[12500:21000],linestyle='dashed', c="black")
major_ticksx3 = np.arange(0,20,2)
major_ticksy3 = np.arange(0, 2.25, 0.5)
ax1.set_xticks(major_ticksx3)
ax1.set_yticks(major_ticksy3)
ax1.tick_params(axis='both', which='major', labelsize=25)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)

#ax2.set_title("(SOFT OBJ) SENSING stage | Vel=5mm/sec")
time_ss_5= np.linspace(0, 52.0, 26000)
hall_real_ss_5 = -df4["real_hall"]
hall_des_ss_5 = df4["desired_hall"]
ax2.plot(time_ss_5[0:8500], hall_real_ss_5[6500:15000], c="red")
ax2.plot(time_ss_5[0:8500], hall_des_ss_5[6500:15000],linestyle='dashed', c="black")
major_ticksx2 = np.arange(0,20,2)
major_ticksy2 = np.arange(3.0, 5.00, 0.5)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=25)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 25)
ax2.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)
#plt.savefig('soft_5.eps', format='eps')
# Out:
# Text(0,0.5,'$\\mathrm{d, mm}$')

# %% [markdown]
# ## RMSE Vel=5mm/sec | SOFT object | FORCE STATE

# %%
#import necessary libraries
from sklearn.metrics import mean_squared_error
from math import sqrt
plt.figure(figsize=(12,8), dpi= 100) 
error3_soft = hall_des_sf_5[12500:21000] - hall_real_sf_5[12500:21000]
error4_soft = hall_des_ss_5[6500:15000] - hall_real_ss_5[6500:15000]

rmse_sf_5 = mean_squared_error(hall_des_sf_5[12500:21000], hall_real_sf_5[12500:21000])
rmse_ss_5 = mean_squared_error(hall_des_ss_5[6500:15000], hall_real_ss_5[6500:15000])
print(rmse_sf_5)
print(rmse_ss_5)

plt.boxplot([error3_soft, error4_soft],showfliers=False) 
plt.xticks([1, 2], ['Force', 'Sensing'])


plt.show()
# Out:
# 0.48028601494320206
# 0.5436572411976264

# %% [markdown]
# ## Trial 3 Vel=18mm/sec

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
#ax1.set_title("(SOFT OBJ)FORCE stage | Vel=18mm/sec")
time_sf_18= np.linspace(0, 40.0, 20000)
hall_real_sf_18 = -df5["real_hall"]
hall_des_sf_18 = df5["desired_hall"]
ax1.plot(time_sf_18[0:8500], hall_real_sf_18[8500:17000],c="red")
ax1.plot(time_sf_18[0:8500], hall_des_sf_18[8500:17000],linestyle='dashed', c="black")
major_ticksx5 = np.arange(0,20,2)
major_ticksy5 = np.arange(0, 2.25, 0.5)
ax1.set_xticks(major_ticksx5)
ax1.set_yticks(major_ticksy5)
ax1.tick_params(axis='both', which='major', labelsize=25)
ax1.grid(linestyle='dashed')
#ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)

#ax2.set_title("(SOFT OBJ) SENSING stage | Vel=18mm/sec")
time_ss_18= np.linspace(0, 60.0, 30000)
hall_real_ss_18 = -df6["real_hall"]
hall_des_ss_18 = df6["desired_hall"]
ax2.plot(time_ss_18[0:8500], hall_real_ss_18[8500:17000],c="red")
ax2.plot(time_ss_18[0:8500], hall_des_ss_18[8500:17000],linestyle='dashed', c="black")
major_ticksx6 = np.arange(0,20,2)
major_ticksy6 = np.arange(3.0, 5.00, 0.5)
ax2.set_xticks(major_ticksx6)
ax2.set_yticks(major_ticksy6)
ax2.tick_params(axis='both', which='major', labelsize=25)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 25)
ax2.set_ylabel('$\mathrm{d, mm}$',fontsize = 25)
#plt.savefig('soft_18.eps', format='eps')
# Out:
# Text(0,0.5,'$\\mathrm{d, mm}$')

# %% [markdown]
# ## RMSE Vel=18mm/sec | SOFT OBJECT | FORCE STATE

# %%
#import necessary libraries
from sklearn.metrics import mean_squared_error
from math import sqrt
plt.figure(figsize=(12,8), dpi= 100) 
error5_soft = hall_des_sf_18[8500:17000] - hall_real_sf_18[8500:17000]
error6_soft = hall_des_ss_18[8500:17000] - hall_real_ss_18[8500:17000]

rmse_sf_18 = mean_squared_error(hall_des_sf_18[8500:17000], hall_real_sf_18[8500:17000])
rmse_ss_18 = mean_squared_error(hall_des_ss_18[8500:17000], hall_real_ss_18[8500:17000])
print(rmse_sf_18)
print(rmse_ss_18)

plt.boxplot([error5_soft, error6_soft],showfliers=False) 
plt.xticks([1, 2], ['Force', 'Sensing'])
plt.show()
# Out:
# 0.1182598624131869
# 0.3471663506616666

# %% [markdown]
# ## All RMSE

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,figsize=(10,14), dpi= 200, facecolor='w', edgecolor='k')
ax1.boxplot([error3_rigid, error3_rigid,error4_soft, error4_soft],showfliers=False) 
ax1.set_xticks([1,2,3,4])
ax1.set_xticklabels(['object: rigid\nstate: force\nvel5', 'object: rigid\nstate: sensing\nvel5', 'object: soft\nstate: force\nvel5','object: soft\nstate: sensing\nvel5'])
ax2.boxplot([error5_rigid, error5_rigid,error6_soft, error6_soft],showfliers=False) 
ax2.set_xticks([1,2,3,4])
ax2.set_xticklabels(['object:rigid\nstate:force\nvel18', 'object:rigid\nstate:sensing\nvel18', 'object:soft\nstate:force\nvel18','object:soft\nstate:sensing\nvel18'])
#ax2.set_xticklabels([1,2,3,4], ['RIGID\nFORCE\nvel18', 'RIGID\nSENSING\nvel18', 'SOFT\nFORCE\nvel18','SOFT\nSENSING\nvel18'])
ax3.boxplot([error1_rigid, error2_rigid,error1_soft, error2_soft],showfliers=False) 
ax3.set_xticks([1,2,3,4])
ax3.set_xticklabels(['object:rigid\nstate:force\nvel33', 'object:rigid\nstate:sensing\nvel33', 'object:soft\nstate:force\nvel33','object:soft\nstate:sensing\nvel33'])
ax1.set_ylabel('$\mathrm{d, mm}$',fontsize = 10)
ax2.set_ylabel('$\mathrm{d, mm}$',fontsize = 10)
ax3.set_ylabel('$\mathrm{d, mm}$',fontsize = 10)
major_ticksy1 = np.arange(-3.00, 3.00, 0.5)
ax1.set_yticks(major_ticksy1)
ax2.set_yticks(major_ticksy1)
ax3.set_yticks(major_ticksy1)
ax1.grid(linestyle='dashed', alpha = 0.3)
ax2.grid(linestyle='dashed', alpha = 0.3)
ax3.grid(linestyle='dashed', alpha = 0.3)
#ax1.grid(linestyle='dashed')
#ax2.grid(linestyle='dashed')
#ax3.grid(linestyle='dashed')
#ax3.xticks([1,2,3,4], ['RIGID\nFORCE\nvel33', 'RIGID\nSENSING\nvel33', 'SOFT\nFORCE\nvel33','SOFT\nSENSING\nvel33'])

# %% [markdown]
# # Control graphs together

# %%
fig, axs = plt.subplots(3,2,figsize=(10,14), dpi= 100, facecolor='w', edgecolor='k')

major_ticksx = np.arange(0,20,5)
major_ticksy = np.arange(0.0, 6.00, 2.0)

#Rigid 5
axs[0,0].plot(time_rf_5[0:8500], hall_real_rf_5[8500:17000], c="red")
axs[0,0].plot(time_rf_5[0:8500], hall_des_rf_5[8500:17000],linestyle='dashed', c="black")
axs[0,0].plot(time_rs_5[0:8500], hall_real_rs_5[8500:17000], c="b")
axs[0,0].plot(time_rs_5[0:8500], hall_des_rs_5[8500:17000],linestyle='dashed', c="black")
axs[0,0].grid(linestyle='dashed')
axs[0,0].set_xticks(major_ticksx)
axs[0,0].set_yticks(major_ticksy)
axs[0,0].tick_params(axis='both', which='major', labelsize=25)
#Rigid 18
axs[1,0].plot(time_rf_18[0:8500], hall_real_rf_18[8500:17000],c="red")
axs[1,0].plot(time_rf_18[0:8500], hall_des_rf_18[8500:17000],linestyle='dashed', c="black")
axs[1,0].plot(time_rs_18[0:8500], hall_real_rs_18[8500:17000],c="b")
axs[1,0].plot(time_rs_18[0:8500], hall_des_rs_18[8500:17000],linestyle='dashed', c="black")
axs[1,0].grid(linestyle='dashed')
axs[1,0].set_xticks(major_ticksx)
axs[1,0].set_yticks(major_ticksy)
axs[1,0].tick_params(axis='both', which='major', labelsize=25)
#Rigid 33
axs[2,0].plot(time_rf_33[0:8500], hall_real_rf_33[2500:11000], c = "r")
axs[2,0].plot(time_rf_33[0:8500], hall_des_rf_33[2500:11000],linestyle='dashed', c="black")
axs[2,0].plot(time_rs_33[0:8500], hall_real_rs_33[6500:15000], c="b")
axs[2,0].plot(time_rs_33[0:8500], hall_des_rs_33[6500:15000],linestyle='dashed', c="black")
axs[2,0].grid(linestyle='dashed')
axs[2,0].set_xticks(major_ticksx)
axs[2,0].set_yticks(major_ticksy)
axs[2,0].tick_params(axis='both', which='major', labelsize=25)

#Soft 5
axs[0,1].plot(time_sf_5[0:8500], hall_real_sf_5[12500:21000], c="red")
axs[0,1].plot(time_sf_5[0:8500], hall_des_sf_5[12500:21000],linestyle='dashed', c="black")
axs[0,1].plot(time_ss_5[0:8500], hall_real_ss_5[6500:15000], c="b")
axs[0,1].plot(time_ss_5[0:8500], hall_des_ss_5[6500:15000],linestyle='dashed', c="black")
axs[0,1].grid(linestyle='dashed')
axs[0,1].set_xticks(major_ticksx)
axs[0,1].set_yticks(major_ticksy)
axs[0,1].tick_params(axis='both', which='major', labelsize=25)
#Soft 18
axs[1,1].plot(time_sf_18[0:8500], hall_real_sf_18[8500:17000],c="red")
axs[1,1].plot(time_sf_18[0:8500], hall_des_sf_18[8500:17000],linestyle='dashed', c="black")
axs[1,1].plot(time_ss_18[0:8500], hall_real_ss_18[8500:17000],c="b")
axs[1,1].plot(time_ss_18[0:8500], hall_des_ss_18[8500:17000],linestyle='dashed', c="black")
axs[1,1].grid(linestyle='dashed')
axs[1,1].set_xticks(major_ticksx)
axs[1,1].set_yticks(major_ticksy)
axs[1,1].tick_params(axis='both', which='major', labelsize=25)
#Soft 33
axs[2,1].plot(time_sf_33[0:8500], hall_real_sf_33[2500:11000], c="red")
axs[2,1].plot(time_sf_33[0:8500], hall_des_sf_33[2500:11000],linestyle='dashed', c="black")
axs[2,1].plot(time_ss_33[0:8500], hall_real_ss_33[4500:13000], c="b")
axs[2,1].plot(time_ss_33[0:8500], hall_des_ss_33[4500:13000],linestyle='dashed', c="black")
axs[2,1].grid(linestyle='dashed')
axs[2,1].set_xticks(major_ticksx)
axs[2,1].set_yticks(major_ticksy)
axs[2,1].tick_params(axis='both', which='major', labelsize=25)


plt.show()

# %%
print(rmse_rf_33)
print(rmse_rs_33)
print(rmse_rf_18)
print(rmse_rs_18)
print(rmse_rf_5)
print(rmse_rs_5)

print(rmse_sf_33)
print(rmse_ss_33)
print(rmse_sf_18)
print(rmse_ss_18)
print(rmse_sf_5)
print(rmse_ss_5)
# Out:
# 0.09297919308603544
# 0.263707768827048
# 0.1725403842358302
# 0.30422439841821386
# 0.3539553650802928
# 0.2989924070942038
# 1.7254065185155196
# 0.24342941191496148
# 0.1182598624131869
# 0.3471663506616666
# 0.48028601494320206
# 0.5436572411976264

# %%
import matplotlib.transforms as mtrans
fig, axs = plt.subplots(6,2,figsize=(8,10), dpi= 100, facecolor='w', edgecolor='k')

major_ticksx_f = np.arange(0,20,5)
major_ticksy_f = np.arange(0.0, 4.00, 2.0)
major_ticksx_s = np.arange(0,20,5)
major_ticksy_s = np.arange(3.0, 7.00, 2.0)

#Rigid 5
axs[1,0].plot(time_rf_5[0:8500], hall_real_rf_5[8500:17000], c="red")
axs[1,0].plot(time_rf_5[0:8500], hall_des_rf_5[8500:17000],linestyle='dashed', c="black")
axs[0,0].plot(time_rs_5[0:8500], hall_real_rs_5[8500:17000], c="b")
axs[0,0].plot(time_rs_5[0:8500], hall_des_rs_5[8500:17000],linestyle='dashed', c="black")

#Rigid 18
axs[3,0].plot(time_rf_18[0:8500], hall_real_rf_18[8500:17000],c="red")
axs[3,0].plot(time_rf_18[0:8500], hall_des_rf_18[8500:17000],linestyle='dashed', c="black")
axs[2,0].plot(time_rs_18[0:8500], hall_real_rs_18[8500:17000],c="b")
axs[2,0].plot(time_rs_18[0:8500], hall_des_rs_18[8500:17000],linestyle='dashed', c="black")

#Rigid 33
axs[5,0].plot(time_rf_33[0:8500], hall_real_rf_33[2500:11000], c = "r")
axs[5,0].plot(time_rf_33[0:8500], hall_des_rf_33[2500:11000],linestyle='dashed', c="black")
axs[4,0].plot(time_rs_33[0:8500], hall_real_rs_33[6500:15000], c="b")
axs[4,0].plot(time_rs_33[0:8500], hall_des_rs_33[6500:15000],linestyle='dashed', c="black")


#Soft 5
axs[1,1].plot(time_sf_5[0:8500], hall_real_sf_5[12500:21000], c="red")
axs[1,1].plot(time_sf_5[0:8500], hall_des_sf_5[12500:21000],linestyle='dashed', c="black")
axs[0,1].plot(time_ss_5[0:8500], hall_real_ss_5[6500:15000], c="b")
axs[0,1].plot(time_ss_5[0:8500], hall_des_ss_5[6500:15000],linestyle='dashed', c="black")

#Soft 18
axs[3,1].plot(time_sf_18[0:8500], hall_real_sf_18[8500:17000],c="red")
axs[3,1].plot(time_sf_18[0:8500], hall_des_sf_18[8500:17000],linestyle='dashed', c="black")
axs[2,1].plot(time_ss_18[0:8500], hall_real_ss_18[8500:17000],c="b")
axs[2,1].plot(time_ss_18[0:8500], hall_des_ss_18[8500:17000],linestyle='dashed', c="black")

#Soft 33
axs[5,1].plot(time_sf_33[0:8500], hall_real_sf_33[2500:11000], c="red")
axs[5,1].plot(time_sf_33[0:8500], hall_des_sf_33[2500:11000],linestyle='dashed', c="black")
axs[4,1].plot(time_ss_33[0:8500], hall_real_ss_33[4500:13000], c="b")
axs[4,1].plot(time_ss_33[0:8500], hall_des_ss_33[4500:13000],linestyle='dashed', c="black")


for i in range(6):
    for j in range(2):        
        if i == 5 and j == 0:
            #axs[i,j].grid(linestyle='dashed')
            axs[i,j].set_xticks(major_ticksx_f)
            axs[i,j].set_yticks(major_ticksy_f)
            axs[i,j].tick_params(axis='both', which='major', labelsize=20)
            axs[i,j].set_xlabel('time, s',fontsize = 20)
            
        elif i == 5 and j == 1:
            #axs[i,j].grid(linestyle='dashed')
            axs[i,j].set_xticks(major_ticksx_f)
            axs[i,j].set_yticks(major_ticksy_f)
            axs[i,j].tick_params(axis='both', which='major', labelsize=20)  
            axs[i,j].set_xlabel('time, s',fontsize = 20)      
                  
            #axs[i,j].get_yaxis().set_visible(False)
        elif i%2!=0 and j == 0:
            #axs[i,j].grid(linestyle='dashed')
            axs[i,j].set_xticks(major_ticksx_f)
            axs[i,j].set_yticks(major_ticksy_f)
            axs[i,j].tick_params(axis='both', which='major', labelsize=20)
            axs[i,j].get_xaxis().set_visible(False)
            axs[i,j].set_ylabel(" ",fontsize = 20)
        elif i%2==0 and j == 0:            
            #axs[i,j].grid(linestyle='dashed')
            axs[i,j].set_xticks(major_ticksx_s)
            axs[i,j].set_yticks(major_ticksy_s)
            axs[i,j].tick_params(axis='both', which='major', labelsize=20)   
            axs[i,j].get_xaxis().set_visible(False)  
                    
        else:
            axs[i,j].get_xaxis().set_visible(False)
            axs[i,j].get_yaxis().set_visible(False)
            
fig.text(0.0, 0.23, r'$\Delta$, mm', va='center', rotation='vertical',fontsize=25)  
fig.text(0.0, 0.53, r'$\Delta$, mm', va='center', rotation='vertical',fontsize=25) 
fig.text(0.0, 0.83, r'$\Delta$, mm', va='center', rotation='vertical',fontsize=25)      
fig.text(0.3, 0.95, 'Rigid', ha='center', rotation='horizontal',fontsize=25)  
fig.text(0.75, 0.95, 'Soft', ha='center', rotation='horizontal',fontsize=25)     
fig.text(0.5, 0.653, '------------------------------------------------------------------', ha='center', rotation='horizontal',fontsize=25) 
fig.text(0.5, 0.358, '------------------------------------------------------------------', ha='center', rotation='horizontal',fontsize=25) 
fig.text(0.51, 0.80, "slow", va='center', rotation='horizontal',fontsize=15, style='italic',fontweight="bold") 
fig.text(0.485, 0.51, "medium", va='center', rotation='horizontal',fontsize=15, style='italic',fontweight="bold") 
fig.text(0.51, 0.21, "fast", va='center', rotation='horizontal',fontsize=15, style='italic',fontweight="bold") 

fig.text(0.35, 0.938, "RMSE:"+"{:.3f}".format(rmse_rs_5), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.35, 0.795, "RMSE:"+"{:.3f}".format(rmse_rf_5), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.85, 0.938, "RMSE:"+"{:.3f}".format(rmse_sf_5), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.85, 0.795, "RMSE:"+"{:.3f}".format(rmse_ss_5), va='center', rotation='horizontal', fontsize=12, style='italic') 


fig.text(0.35, 0.647, "RMSE:"+"{:.3f}".format(rmse_rs_18), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.85, 0.647, "RMSE:"+"{:.3f}".format(rmse_ss_18), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.35, 0.50, "RMSE:"+"{:.3f}".format(rmse_rf_18), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.85, 0.50, "RMSE:"+"{:.3f}".format(rmse_sf_18), va='center', rotation='horizontal', fontsize=12, style='italic') 

fig.text(0.35, 0.353, "RMSE:"+"{:.3f}".format(rmse_rs_33), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.85, 0.353, "RMSE:"+"{:.3f}".format(rmse_ss_33), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.35, 0.208, "RMSE:"+"{:.3f}".format(rmse_rf_33), va='center', rotation='horizontal', fontsize=12, style='italic') 
fig.text(0.85, 0.208, "RMSE:"+"{:.3f}".format(rmse_sf_33), va='center', rotation='horizontal', fontsize=12, style='italic') 

#fig.suptitle('Main title')
plt.tight_layout()
plt.suptitle(" ", size=5)
fig.subplots_adjust(top=0.93)
plt.savefig('control_graph_together.pdf', format='pdf')
#plt.show()

# %% [markdown]
# # Force under precompressions

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from datetime import datetime
from random import sample
import pandas as pd
import time
import numpy as np
df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/trial1.csv", skiprows=[i for i in range(1, 2000)], skipfooter=2000)
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/trial2.csv", skiprows=[i for i in range(1, 2000)], skipfooter=4000)
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/trial3.csv", skiprows=[i for i in range(1, 2000)], skipfooter=4000)
fig, (ax1, ax2) = plt.subplots(2,figsize=(17,13), dpi= 300, facecolor='w', edgecolor='k')
#ax2 = fig.add_subplot(1, 1, 1)

#df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/trial1.csv")

time1 = np.linspace(0, 22.0, 10001)
time2 = np.linspace(0, 22.0, 10001)
pseudo_force1 = df1["fz"]
pseudo_force2 = df2["fz"]
pseudo_force3 = df3["fz"]
hall_real1 = -df1["real_hall"]
hall_des1 = df1["desired_hall"]
hall_real2 = -df2["real_hall"]
hall_des2 = df2["desired_hall"]
hall_real3 = -df3["real_hall"]
hall_des3 = df3["desired_hall"]

#ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(time1, hall_real1, c="blue")
ax1.plot(time1, hall_des1,c="black",linestyle='dashed')
ax1.plot(time1, hall_real2,c="red")
ax1.plot(time1, hall_des2, c="black",linestyle='dashed')
ax1.plot(time1, hall_real3,c="green")
ax1.plot(time1, hall_des3, c="black",linestyle='dashed')
major_ticksx = np.arange(0, 25.0, 2)
major_ticksy = np.arange(0, 6.5, 1.0)
ax1.set_xticks(major_ticksx)
ax1.set_yticks(major_ticksy)
ax1.tick_params(axis='both', which='major', labelsize=25)
#plt.xticks(range(0, 32))
ax1.grid(linestyle='dashed')
ax1.set_ylabel('Displacement, mm',fontsize = 25)
#L = ax.legend()
#L.get_texts()[0].set_text("Real Hall #1")
#L.get_texts()[1].set_text("Desired Hall #1")
#L.get_texts()[2].set_text("Real Hall #2")
#L.get_texts()[3].set_text("Desired Hall #2")
#L.get_texts()[4].set_text("Real Hall #3")
#L.get_texts()[5].set_text("Desired Hall #3")



#ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(time2, pseudo_force1,color="blue")
ax2.plot(time2, pseudo_force2,color="red")
ax2.plot(time2, pseudo_force3,color="green")
major_ticksx = np.arange(0, 25.0, 2)
major_ticksy = np.arange(0, 60.0, 10)
ax2.set_xticks(major_ticksx)
ax2.set_yticks(major_ticksy)
ax2.tick_params(axis='both', which='major', labelsize=25)
#plt.xticks(range(0, 32))
ax2.grid(linestyle='dashed')
ax2.set_xlabel('Time, s',fontsize = 25)
ax2.set_ylabel('Force, N',fontsize = 25)
#L = ax.legend()
#L.get_texts()[0].set_text("Force #1")
#L.get_texts()[1].set_text("Force #2")
#L.get_texts()[2].set_text("Force #3")

#for i in range(0,10):
#    L.get_texts()[i].set_text("trial%01d" % (i+1))
plt.savefig('three_trials.eps', format='eps')
plt.show()
# Out:
# /home/rustam/.local/lib/python2.7/site-packages/ipykernel_launcher.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#
# /home/rustam/.local/lib/python2.7/site-packages/ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# /home/rustam/.local/lib/python2.7/site-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.
