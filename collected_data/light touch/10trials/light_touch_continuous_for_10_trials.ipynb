# %% [markdown]
# # Force under 3 precompressed level

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from datetime import datetime
from random import sample
import pandas as pd
import time
import numpy as np

df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/trial1.csv", skiprows=[i for i in range(1, 2000)], skipfooter=2000,engine='python')
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/trial2.csv", skiprows=[i for i in range(1, 2000)], skipfooter=4000,engine='python')
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/vel control/trial3.csv", skiprows=[i for i in range(1, 2000)], skipfooter=4000,engine='python')
fig, axs = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
time1 = np.linspace(0, 22.0, 10001)
time2 = np.linspace(0, 22.0, 10001)
pseudo_force1 = df1["fz"]
pseudo_force2 = df2["fz"]
pseudo_force3 = df3["fz"]
hall_real1 = -df1["real_hall"]
hall_des1 = df1["desired_hall"]
hall_real2 = -df2["real_hall"]
hall_des2 = df2["desired_hall"]
hall_real3 = -df3["real_hall"]
hall_des3 = df3["desired_hall"]

axs[0].plot(time1, hall_real1, c="blue")
axs[0].plot(time1, hall_des1,c="black",linestyle='dashed')
axs[0].plot(time1, hall_real2,c="red")
axs[0].plot(time1, hall_des2, c="black",linestyle='dashed')
axs[0].plot(time1, hall_real3,c="green")
axs[0].plot(time1, hall_des3, c="black",linestyle='dashed')
major_ticksx = np.arange(0, 22.0, 5)
major_ticksy = np.arange(0, 8, 2)
axs[0].set_xticks(major_ticksx)
axs[0].set_yticks(major_ticksy)
axs[0].tick_params(axis='both', which='major', labelsize=20)
axs[0].grid(linestyle='dashed')
axs[0].set_ylabel('Displacement, mm',fontsize = 20)


axs[1].plot(time2, pseudo_force1,color="blue")
axs[1].plot(time2, pseudo_force2,color="red")
axs[1].plot(time2, pseudo_force3,color="green")
major_ticksx = np.arange(0, 22.0, 5)
major_ticksy = np.arange(0, 70.0, 15)
axs[1].set_xticks(major_ticksx)
axs[1].set_yticks(major_ticksy)
axs[1].tick_params(axis='both', which='major', labelsize=20)
axs[1].grid(linestyle='dashed')
axs[1].set_xlabel('Time, s',fontsize = 20)
axs[1].set_ylabel('Force, N',fontsize = 20)

plt.show()

# %% [markdown]
# ## Force 10 trials [0.85-1.0]

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import time
import numpy as np
df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/trial1.csv")
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/trial2.csv")
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/trial3.csv")
df4 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/trial4.csv")
df5 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/trial5.csv")
#df_fd = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/Force vs Distance/New Force Distance/trial3.csv",skiprows=0)
#df6 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/trial6.csv")
#df7 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/trial7.csv")

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import time
import numpy as np
df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial1/trial1.csv")
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial2/trial2.csv")
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial3/trial3.csv")
df4 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial4/trial4.csv")
df5 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial5/trial5.csv")
df6 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial6/trial6.csv")
df7 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial7/trial7.csv")
df8 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial8/trial8.csv")
df9 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial9/trial9.csv")
df10 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial10/trial10.csv")

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
#fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
#ax = fig.add_subplot(1, 1, 1)
ax1.set_title("light touch #1")

time1= np.linspace(0, 17.5, 8732)
time2= np.linspace(0, 17.0, 8495)
time3= np.linspace(0, 15.8, 7917)
time4= np.linspace(0, 15.7, 7848)
time5= np.linspace(0, 16.7, 8349)
time6= np.linspace(0, 15.5, 7749)
time7= np.linspace(0, 17.7, 8857)
time8= np.linspace(0, 16.8, 8415)
time9= np.linspace(0, 15.4, 7696)
time10= np.linspace(0, 15.9, 7930)
force1 = -df1["fz"]
hall1 = df1["top"]
force2 = -df2["fz"]
hall2 = df2["top"]
force3 = -df3["fz"]
hall3 = df3["top"]
force4 = -df4["fz"]
hall4 = df4["top"]
force5 = -df5["fz"]
hall5 = df5["top"]
force6 = -df6["fz"]
hall6 = df6["top"]
force7 = -df7["fz"]
hall7 = df7["top"]
force8 = -df8["fz"]
hall8 = df8["top"]
force9 = -df9["fz"]
hall9 = df9["top"]
force10 = -df10["fz"]
hall10 = df10["top"]
ax1.plot(time1, force1)
ax1.plot(time2, force2)
ax1.plot(time3, force3)
ax1.plot(time4, force4)
ax1.plot(time5, force5)
ax1.plot(time6, force6)
ax1.plot(time7, force7)
ax1.plot(time8, force8)
ax1.plot(time9, force9)
ax1.plot(time10, force10)
ax2.plot(time1[1:], hall1[1:])
ax2.plot(time2[1:], hall2[1:])
ax2.plot(time3[1:], hall3[1:])
ax2.plot(time4[1:], hall4[1:])
ax2.plot(time5[1:], hall5[1:])
ax2.plot(time6[1:], hall6[1:])
ax2.plot(time7[1:], hall7[1:])
ax2.plot(time8[1:], hall8[1:])
ax2.plot(time9[1:], hall9[1:])
ax2.plot(time10[1:], hall10[1:])
ax1.grid(linestyle='dashed')
ax2.grid(linestyle='dashed')

# %%
len(force3)
# Out:
# 7917

# %% [markdown]
# ## Final graph

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import time
import numpy as np
df1_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial1/trial1.csv")
df2_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial2/trial2.csv")
df3_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial3/trial3.csv")
df4_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial4/trial4.csv")
df5_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial5/trial5.csv")
df6_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial6/trial6.csv")
df7_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial7/trial7.csv")
df8_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial8/trial8.csv")
df9_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial9/trial9.csv")
df10_1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state1/trial10/trial10.csv")

df1_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial1/trial1.csv")
df2_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial2/trial2.csv")
df3_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial3/trial3.csv")
df4_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial4/trial4.csv")
df5_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial5/trial5.csv")
df6_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial6/trial6.csv")
df7_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial7/trial7.csv")
df8_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial8/trial8.csv")
df9_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial9/trial9.csv")
df10_2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial10/trial10.csv")
force1_1 = -df1_1["fz"]
force2_1 = -df2_1["fz"]
force3_1 = -df3_1["fz"]
force4_1 = -df4_1["fz"]
force5_1 = -df5_1["fz"]
force6_1 = -df6_1["fz"]
force7_1 = -df7_1["fz"]
force8_1 = -df8_1["fz"]
force9_1 = -df9_1["fz"]
force10_1 = -df10_1["fz"]
hall1_1 = df1_1["top"]
hall2_1 = df2_1["top"]
hall3_1 = df3_1["top"]
hall4_1 = df4_1["top"]
hall5_1 = df5_1["top"]
hall6_1 = df6_1["top"]
hall7_1 = df7_1["top"]
hall8_1 = df8_1["top"]
hall9_1 = df9_1["top"]
hall10_1 = df10_1["top"]

force1_2 = -df1_2["fz"]
force2_2 = -df2_2["fz"]
force3_2 = -df3_2["fz"]
force4_2 = -df4_2["fz"]
force5_2 = -df5_2["fz"]
force6_2 = -df6_2["fz"]
force7_2 = -df7_2["fz"]
force8_2 = -df8_2["fz"]
force9_2 = -df9_2["fz"]
force10_2 = -df10_2["fz"]
hall1_2 = df1_2["top"]
hall2_2 = df2_2["top"]
hall3_2 = df3_2["top"]
hall4_2 = df4_2["top"]
hall5_2 = df5_2["top"]
hall6_2 = df6_2["top"]
hall7_2 = df7_2["top"]
hall8_2 = df8_2["top"]
hall9_2 = df9_2["top"]
hall10_2 = df10_2["top"]

# %% [markdown]
# ### Mean of State 1

# %%
li_state1 = []
li_state1.append(force1_1[len(force1_1)-574:].values)
li_state1.append(force2_1[len(force2_1)-574:].values)
li_state1.append(force3_1[len(force3_1)-574:].values)
li_state1.append(force4_1[len(force4_1)-574:].values)
li_state1.append(force5_1[len(force5_1)-574:].values)
li_state1.append(force6_1[len(force6_1)-574:].values)
li_state1.append(force7_1[len(force7_1)-574:].values)
li_state1.append(force8_1[len(force8_1)-574:].values)
li_state1.append(force9_1[len(force9_1)-574:].values)
li_state1.append(force10_1[len(force10_1)-574:].values)
ncols = len(li_state1)
nrows = len(li_state1[0])
results_state1 = nrows*[0] # sums per column, afterwards avgs
num_elem = ncols
for row in range(nrows):
    for col in range(ncols):
        results_state1[row] += li_state1[col][row]
    results_state1[row] /= num_elem

# %% [markdown]
# ### Mean of State 2

# %%
li_state2 = []
li_state2.append(force1_2[len(force1_2)-574:].values)
li_state2.append(force2_2[len(force2_2)-574:].values)
li_state2.append(force3_2[len(force3_2)-574:].values)
li_state2.append(force4_2[len(force4_2)-574:].values)
li_state2.append(force5_2[len(force5_2)-574:].values)
li_state2.append(force6_2[len(force6_2)-574:].values)
li_state2.append(force7_2[len(force7_2)-574:].values)
li_state2.append(force8_2[len(force8_2)-574:].values)
li_state2.append(force9_2[len(force9_2)-574:].values)
li_state2.append(force10_2[len(force10_2)-574:].values)
#merged_state1 = pd.concat(li_state1, axis=1, ignore_index=True)

#merged_state1['mean'] = merged_state1.iloc[0:, 0:9].median(axis=1, skipna=True, numeric_only=None)
#print(merged_state1['mean'].shape)
#print(merged_state1.shape)
ncols = len(li_state2)
nrows = len(li_state2[0])
results_state2 = nrows*[0] # sums per column, afterwards avgs
num_elem = ncols
for row in range(nrows):
    for col in range(ncols):
        results_state2[row] += li_state2[col][row]
    results_state2[row] /= num_elem
    
#print(len(results_state2))

# %%
fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(1, 1, 1)

x1_1 = np.linspace(0, 2, 574)
x2_1 = np.linspace(0, 2, 574)
x3_1 = np.linspace(0, 2, 574)
x4_1 = np.linspace(0, 2, 574)
x5_1 = np.linspace(0, 2, 574)
x6_1 = np.linspace(0, 2, 574)
x7_1 = np.linspace(0, 2, 574)
x8_1 = np.linspace(0, 2, 574)
x9_1 = np.linspace(0, 2, 574)
x10_1 = np.linspace(0, 2, 574)
x_mean_1 = np.linspace(0, 2, 574)
x_mean_2 = np.linspace(3, 5, 574)

ax.scatter(x1_1, force1_1[len(force1_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x2_1, force2_1[len(force2_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x3_1, force3_1[len(force3_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x4_1, force4_1[len(force4_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x5_1, force5_1[len(force5_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x6_1, force6_1[len(force6_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x7_1, force7_1[len(force7_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x8_1, force8_1[len(force8_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x9_1, force9_1[len(force9_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
ax.scatter(x10_1, force10_1[len(force10_1)-574:], alpha=1,s = 15,c='dimgray',marker='.')
#ax.scatter(x_mean_1, results_state1, alpha=1,c = 'firebrick',s = 30,marker='o',edgecolors='orange',linewidth=0.4)
ax.scatter(x_mean_1, results_state1, alpha=1,c = 'firebrick',s = 30,marker='.')
ax.scatter(x_mean_1[np.argmax(results_state1[:200])], max(results_state1[:200]), marker = 'X', c = "darkgreen",edgecolors='orange', s = 60,linewidth=1)
ax.text(x_mean_1[np.argmax(results_state1[:200])]-0.55, max(results_state1[:200]), '{:.2f}N'.format(max(results_state1[:200])), size = 15,weight='bold')

x1_2 = np.linspace(3, 5, 574)
x2_2 = np.linspace(3, 5, 574)
x3_2 = np.linspace(3, 5, 574)
x4_2 = np.linspace(3, 5, 574)
x5_2 = np.linspace(3, 5, 574)
x6_2 = np.linspace(3, 5, 574)
x7_2 = np.linspace(3, 5, 574)
x8_2 = np.linspace(3, 5, 574)
x9_2 = np.linspace(3, 5, 574)
x10_2 = np.linspace(3, 5, 574)

ax.scatter(x1_2, force1_2[len(force1_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x2_2, force2_2[len(force2_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x3_2, force3_2[len(force3_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x4_2, force4_2[len(force4_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x5_2, force5_2[len(force5_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x6_2, force6_2[len(force6_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x7_2, force7_2[len(force7_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x8_2, force8_2[len(force8_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x9_2, force9_2[len(force9_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x10_2, force10_2[len(force10_2)-574:], alpha=1,s = 15,marker='.',c='dimgray')
ax.scatter(x_mean_2, results_state2, alpha=1,c = 'firebrick',s = 30,marker='.')
ax.scatter(x_mean_2[np.argmax(results_state2[:200])], max(results_state2[:200]), marker = 'X', c = "darkgreen",edgecolors='orange', s = 60,linewidth=1)
ax.text(x_mean_2[np.argmax(results_state2[:200])]-0.55, max(results_state2[:200]), '{:.2f}N'.format(max(results_state2[:200])), size = 15,weight='bold')

major_ticksx = [0,3,6]
states = ['state 1', 'state 2']
major_ticksy = np.arange(0, 20, 5)
ax.set_xticks(major_ticksx)
ax.set_xticklabels(states, minor=False)
ax.set_yticks(major_ticksy)
ax.tick_params(axis='x', which='major', labelsize=30)
ax.tick_params(axis='y', which='major', labelsize=30)
ax.grid(linestyle='dashed', alpha = 0.3)
ax.set_ylabel('Force, N',fontsize = 30)
ax.set_axisbelow(True)
plt.savefig('/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/light_touch_10trials_mean.png', format='png')

# %% [markdown]
# # Sensing 10 trials [2.85-3.0]

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import time
import numpy as np
df1 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial1/trial1.csv")
df2 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial2/trial2.csv")
df3 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial3/trial3.csv")
df4 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial4/trial4.csv")
df5 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial5/trial5.csv")
df6 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial6/trial6.csv")
df7 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial7/trial7.csv")
df8 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial8/trial8.csv")
df9 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial9/trial9.csv")
df10 = pd.read_csv("/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/10trials/state2/trial10/trial10.csv")



fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
#fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
#ax = fig.add_subplot(1, 1, 1)
ax1.set_title("light touch #1")

time1= np.linspace(0, 15.8, 7884)
time2= np.linspace(0, 15.3, 7673)
time3= np.linspace(0, 16.1, 8067)
time4= np.linspace(0, 16.0, 8004)
time5= np.linspace(0, 15.4, 7708)
time6= np.linspace(0, 16.9, 8437)
time7= np.linspace(0, 16.9, 8457)
time8= np.linspace(0, 16.2, 8125)
time9= np.linspace(0, 16.9, 8458)
time10= np.linspace(0, 15.8, 7883)
force1 = -df1["fz"]
hall1 = df1["top"]
force2 = -df2["fz"]
hall2 = df2["top"]
force3 = -df3["fz"]
hall3 = df3["top"]
force4 = -df4["fz"]
hall4 = df4["top"]
force5 = -df5["fz"]
hall5 = df5["top"]
force6 = -df6["fz"]
hall6 = df6["top"]
force7 = -df7["fz"]
hall7 = df7["top"]
force8 = -df8["fz"]
hall8 = df8["top"]
force9 = -df9["fz"]
hall9 = df9["top"]
force10 = -df10["fz"]
hall10 = df10["top"]
ax1.plot(time1, force1)
ax1.plot(time2, force2)
ax1.plot(time3, force3)
ax1.plot(time4, force4)
ax1.plot(time5, force5)
ax1.plot(time6, force6)
ax1.plot(time7, force7)
ax1.plot(time8, force8)
ax1.plot(time9, force9)
ax1.plot(time10, force10)
ax2.plot(time1[1:], hall1[1:])
ax2.plot(time2[1:], hall2[1:])
ax2.plot(time3[1:], hall3[1:])
ax2.plot(time4[1:], hall4[1:])
ax2.plot(time5[1:], hall5[1:])
ax2.plot(time6[1:], hall6[1:])
ax2.plot(time7[1:], hall7[1:])
ax2.plot(time8[1:], hall8[1:])
ax2.plot(time9[1:], hall9[1:])
ax2.plot(time10[1:], hall10[1:])
ax1.grid(linestyle='dashed')
ax2.grid(linestyle='dashed')

# %% [markdown]
# # OLD

# %% [markdown]
# ## Trial 1 [0.85 0.95]

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
#fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
#ax = fig.add_subplot(1, 1, 1)
ax1.set_title("light touch #1")

time1= np.linspace(0, 7.4, 3721)
force1 = -df1["fz"]
hall1 = df1["top"]

y1 = max(force1)
ax1.plot(time1, force1)

#major_ticksx = np.arange(0,1,0.1)
major_ticksx1 = np.arange(0,8.0,0.5)
major_ticksy1 = np.arange(0, 20, 2)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed')
ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Force, N',fontsize = 15)

L1= ax1.legend(loc=2, prop={'size': 10})
L1.get_texts()[0].set_text("Force peak: {:.2f} N".format(y1))
ax2.plot(time1[1:], hall1[1:])


major_ticksx2 = np.arange(0,8.0,0.5)
#major_ticksy2 = np.arange(0.7, 1.1, 0.05)
major_ticksy2 = np.arange(0.7, 1.1, 0.05)

ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall, mm',fontsize = 15)

ax1.scatter(time1[3219], force1[3219], color = 'r')
ax1.axvline(x = time1[3219], color = 'g', linestyle = '--')
ax1.text(time1[3219]-0.5, force1[3219]+0.2, '{:.2f}N'.format(force1[3219]), size = 10)
ax2.axhline(y = hall1[3219], color = 'g', linestyle = '--')
ax2.axvline(x = time1[3219], color = 'g', linestyle = '--')
ax2.scatter(time1[3219],hall1[3219], color = 'r')


plt.show()

# %% [markdown]
# ## Trial 2 [1.55, 1.65]

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
#fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
#ax = fig.add_subplot(1, 1, 1)
ax1.set_title("light touch #2")

time2= np.linspace(0, 5.7, 3984)
force2 = -df2["fz"]
hall2 = df2["top"]
y2 = max(force2)

ax1.plot(time2, force2)
ax1.scatter(time2[3484], force2[3484], color = 'r')
#major_ticksx = np.arange(0,1,0.1)
major_ticksx1 = np.arange(0,5.0,0.5)
major_ticksy1 = np.arange(0, 20, 2)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed')
ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Force, N',fontsize = 15)
L = ax1.legend(loc=2, prop={'size': 10})
L.get_texts()[0].set_text("Force peak: {:.2f} N".format(y2))

ax2.plot(time2[1:], hall2[1:])



major_ticksx2 = np.arange(0,8.5,0.5)
major_ticksy2 = np.arange(1.3, 1.8, 0.05)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall, mm',fontsize = 15)

ax1.scatter(time2[3484], force2[3484], color = 'r')
ax1.text(time2[3484]-0.4, force2[3484]-0.5, '{:.2f}N'.format(force2[3484]), size = 10)
ax2.axhline(y = hall2[3484], color = 'g', linestyle = '--')
ax2.axvline(x = time2[3484], color = 'g', linestyle = '--')
ax1.axvline(x = time2[3484], color = 'g', linestyle = '--')
ax2.scatter(time2[3484],hall2[3484], color = 'r')

plt.show()

# %% [markdown]
# ## Trial 3 [2.6, 2.7]

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
#fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
#ax = fig.add_subplot(1, 1, 1)
ax1.set_title("light touch #3")

time3= np.linspace(0, 8.6, 4289)
force3 = -df3["fz"]
hall3 = df3["top"]
y3 = max(force3)

ax1.plot(time3, force3)

#major_ticksx = np.arange(0,1,0.1)
major_ticksx1 = np.arange(0,9.5,0.5)
major_ticksy1 = np.arange(0, 20, 2)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed')
ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Force, N',fontsize = 15)
L = ax1.legend(loc=2, prop={'size': 10})
L.get_texts()[0].set_text("Force peak: {:.2f} N".format(y3))


ax2.plot(time3[1:], hall3[1:])


major_ticksx2 = np.arange(0,9.5,0.5)
major_ticksy2 = np.arange(2.4, 2.9, 0.05)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall, mm',fontsize = 15)

ax2.axhline(y = hall3[3789], color = 'g', linestyle = '--')
ax1.scatter(time3[3789], force3[3789], color = 'r')
ax1.text(time3[3789]-0.5, force3[3789]+0.2, '{:.2f}N'.format(force3[3789]), size = 10)
ax2.axvline(x = time3[3789], color = 'g', linestyle = '--')
ax1.axvline(x = time3[3789], color = 'g', linestyle = '--')
ax2.scatter(time3[3789],hall3[3789], color = 'r')

plt.show()

# %% [markdown]
# ## Trial 4 [4.1, 4.2]

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
#fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
#ax = fig.add_subplot(1, 1, 1)
ax1.set_title("light touch #4")

time4 = np.linspace(0, 6.3, 3171)
force4 = -df4["fz"]
hall4 = df4["top"]
y4 = max(force4)

ax1.plot(time4, force4)

#major_ticksx = np.arange(0,1,0.1)
major_ticksx1 = np.arange(0, 7, 0.5)
major_ticksy1 = np.arange(0, 20, 2)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed')
ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Force, N',fontsize = 15)
L = ax1.legend(loc=2, prop={'size': 10})
L.get_texts()[0].set_text("Force peak: {:.2f} N".format(y4))

ax2.plot(time4[1:], hall4[1:])

major_ticksx2 = np.arange(0,7,0.5)
major_ticksy2 = np.arange(3.9, 4.3, 0.05)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall, mm',fontsize = 15)

ax2.axhline(y = hall4[2671], color = 'g', linestyle = '--')
ax1.scatter(time4[2671], force4[2671], color = 'r')
ax1.text(time4[2671]-0.4, force4[2671], '{:.2f}N'.format(force4[2671]), size = 10)
ax2.axvline(x = time4[2671], color = 'g', linestyle = '--')
ax1.axvline(x = time4[2671], color = 'g', linestyle = '--')
ax2.scatter(time4[2671],hall4[2671], color = 'r')

plt.show()

# %% [markdown]
# ## Trial 5 [5.6, 5.7]

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
#fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
#ax = fig.add_subplot(1, 1, 1)
#ax1.set_title("State 5")

time5 = np.linspace(0, 6.6, 3303)
force5 = -df5["fz"]
hall5 = df5["top"]
y5 = max(force5)

ax1.plot(time5, force5)

#major_ticksx = np.arange(0,1,0.1)
major_ticksx1 = np.arange(0,7.5,1)
major_ticksy1 = np.arange(0, 20, 2)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=25)
ax1.grid(linestyle='dashed')
ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Force, N',fontsize = 25)
L = ax1.legend(loc=2, prop={'size': 18})
L.get_texts()[0].set_text("Force peak: {:.2f} N".format(y5))

ax2.plot(time5[1:], hall5[1:])

major_ticksx2 = np.arange(0,7.5,1)
major_ticksy2 = np.arange(5.5, 5.8, 0.05)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=25)
ax2.grid(linestyle='dashed')
ax2.set_xlabel('time, s',fontsize = 25)
ax2.set_ylabel('Hall, mm',fontsize = 25)


ax2.axhline(y = hall5[2803], color = 'g', linestyle = '--')
ax1.scatter(time5[2803], force5[2803], color = 'r')
ax1.text(time5[2803]-0.6, force5[2803]+0.2, '{:.2f}N'.format(force5[2803]), size = 18)
ax2.axvline(x = time5[2803], color = 'g', linestyle = '--')
ax1.axvline(x = time5[2803], color = 'g', linestyle = '--')
ax2.scatter(time5[2803],hall5[2803], color = 'r')

plt.show()

# %% [markdown]
# ## All trials

# %%
from matplotlib.image import imread
from matplotlib.lines import Line2D
fig, axs = plt.subplots(2,2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
ax1 = axs[0,0]
ax2 = axs[1,0]
ax3 = axs[0,1]
ax4 = axs[1,1]
x1 = force1.idxmax()
x2 = force2.idxmax()
x3 = force3.idxmax()
x4 = force4.idxmax()
x5 = force5.idxmax()


ax1.plot(time1, force1, alpha=0.5,linewidth=1.0)
ax1.plot(time2, force2, alpha=0.5,linewidth=1.0)
ax1.plot(time3, force3, alpha=0.5,linewidth=1.0)
ax1.plot(time4, force4, alpha=0.5,linewidth=1.0)
ax1.plot(time5, force5, alpha=0.5,linewidth=1.0)

major_ticksx1 = np.arange(0,9.5,1)
major_ticksy1 = np.arange(0, 20, 2)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='both', which='major', labelsize=10)
ax1.grid(linestyle='dashed', alpha = 0.3)
ax1.set_xlabel('time, s',fontsize = 15)
ax1.set_ylabel('Force, N',fontsize = 15)

ax1.scatter(time1[x1], y1, s = 5)
ax1.text(time1[x1], y1, '{:.2f}N'.format(y1), size = 8)
ax1.scatter(time2[x2], y2, s = 5)
ax1.text(time2[x2], y2, '{:.2f}N'.format(y2), size = 8)
ax1.scatter(time3[x3], y3, s = 5)
ax1.text(time3[x3], y3, '{:.2f}N'.format(y3), size = 8)
ax1.scatter(time4[x4], y4, s = 5)
ax1.text(time4[x4], y4, '{:.2f}N'.format(y4), size = 8)
ax1.scatter(time5[x5], y5, s = 5)
ax1.text(time5[x5], y5, '{:.2f}N'.format(y5), size = 8)

ax1.scatter(time1[3219], force1[3219],c='b', s = 15,marker='x')
ax1.text(time1[3219]-0.45, force1[3219], '{:.2f}N'.format(force1[3219]), size = 8)
ax1.scatter(time2[3484], force2[3484],c = 'orange', s = 15,marker='x')
ax1.text(time2[3484]-0.45, force2[3484], '{:.2f}N'.format(force2[3484]), size = 8)
ax1.scatter(time3[3789], force3[3789], c = 'g', s = 15,marker='x')
ax1.text(time3[3789]-0.4, force3[3789], '{:.2f}N'.format(force3[3789]), size = 8)
ax1.scatter(time4[2671], force4[2671], c = 'r', s = 15,marker='x')
ax1.text(time4[2671]-0.4, force4[2671], '{:.2f}N'.format(force4[2671]), size = 8)
ax1.scatter(time5[2803], force5[2803], c = 'purple', s = 15,marker='x')
ax1.text(time5[2803]-0.4, force5[2803], '{:.2f}N'.format(force5[2803]), size = 8)
#ax1.axvline(x = time1[3219], color = 'b', linestyle = '-',ymin=0.0, ymax=0.80,linewidth=1.0)
#ax1.axvline(x = time2[3484], color = 'orange', linestyle = '-',ymin=0.0, ymax=0.70,linewidth=1.0)
#ax1.axvline(x = time3[3789], color = 'g', linestyle = '-',ymin=0.0, ymax=0.47,linewidth=1.0)
#ax1.axvline(x = time4[2671], color = 'r', linestyle = '-',ymin=0.0, ymax=0.47,linewidth=1.0)
#ax1.axvline(x = time5[2803], color = 'purple', linestyle = '-',ymin=0.0, ymax=0.47,linewidth=1.0)



#ax2 = fig.add_subplot(1, 1, 1)
ax2.plot(time1[1:], hall1[1:], alpha=0.7,linewidth=1.0)
ax2.plot(time2[1:], hall2[1:], alpha=0.7,linewidth=1.0)
ax2.plot(time3[1:], hall3[1:], alpha=0.7,linewidth=1.0)
ax2.plot(time4[1:], hall4[1:], alpha=0.7,linewidth=1.0)
ax2.plot(time5[1:], hall5[1:], alpha=0.7,linewidth=1.0)
scat1 = ax2.scatter(time1[3219],hall1[3219], s = 15,alpha=1,marker='x')
scat2 = ax2.scatter(time2[3484],hall2[3484],  s = 15,alpha=1,marker='x')
scat3 = ax2.scatter(time3[3789],hall3[3789],  s = 15,alpha=1,marker='x')
scat4 = ax2.scatter(time4[2671],hall4[2671],  s = 15,alpha=1,marker='x')
scat5 = ax2.scatter(time5[2803],hall5[2803],  s = 15,alpha=1,marker='x')
legend_elements = [Line2D([0], [0], marker='x', color='b', label='{:.2f}s'.format(time1[3219]),markerfacecolor='b', markersize=5),
                   Line2D([0], [0], marker='x', color='orange', label='{:.2f}s'.format(time2[3484]),markerfacecolor='orange', markersize=5),
                   Line2D([0], [0], marker='x', color='g', label='{:.2f}s'.format(time3[3789]),markerfacecolor='g', markersize=5),
                   Line2D([0], [0], marker='x', color='r', label='{:.2f}s'.format(time4[2671]),markerfacecolor='r', markersize=5),
                   Line2D([0], [0], marker='x', color='purple', label='{:.2f}s'.format(time5[2803]),markerfacecolor='purple', markersize=5), ]


major_ticksx2 = np.arange(0,9.5,1)
major_ticksy2 = np.arange(-0.5, 7.5, 0.5)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='both', which='major', labelsize=10)
ax2.grid(linestyle='dashed', alpha = 0.3)
ax2.set_xlabel('time, s',fontsize = 15)
ax2.set_ylabel('Hall Displacement, mm',fontsize = 15)

#L = ax2.legend(loc=1, prop={'size': 10},handles=[scat1, scat2,scat3,scat4,scat5])
legend1 = ax2.legend(handles=legend_elements, loc="upper right", prop={'size': 6})
legend1.set_title('Touch Detection',prop={'size':6})


#timefd= np.linspace(0, 8.6, 4315)
x = df_fd["top"]
x = -(x - x[1])

force = -df_fd["fz"]
#acc1 = -df1["ax"]
ax4.scatter( 29.5, 0.75,color = 'r',marker='x', s = 15)
ax4.scatter(35,1.45, color = 'r',marker='x', s = 15)
ax4.scatter( 29.5,2.51,color = 'r',marker='x', s = 15)
ax4.scatter(20.8,4.0, color = 'r',marker='x', s = 15)
ax4.scatter(17,5.5, color = 'r',marker='x', s = 15)
ax4.axhline(y = 0.75,xmin=0.0, xmax=0.47, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 1.45,xmin=0.0, xmax=0.55, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 2.51,xmin=0.0, xmax=0.47, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 4.0,xmin=0.0, xmax=0.35, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 5.5,xmin=0.0, xmax=0.28, color = 'g', linestyle = '--',linewidth=1.0)
ax4.text(29.5+1, 0.75-0.1, 'k1', size = 10)
ax4.text( 35+1,1.45-0.1, 'k2', size = 10)
ax4.text( 29.5+1, 2.51-0.1,'k3', size = 10)
ax4.text( 20.8+1,4.0-0.1, 'k4', size = 10)
ax4.text( 17+1,5.5-0.1, 'k5', size = 10)
ax4.plot(force[3200:],x[3200:],linewidth=1.0)



major_ticksx4 = np.arange(0, 70, 5)
major_ticksy4 = np.arange(-0.5, 7.5, 0.5)
ax4.set_xticks(major_ticksx4)
ax4.set_yticks(major_ticksy4)
ax4.tick_params(axis='both', which='major', labelsize=10)
ax4.grid(linestyle='dashed', alpha = 0.3)
ax4.set_ylabel('Hall Displacement, mm',fontsize = 15)
ax4.set_xlabel('Force, N',fontsize = 15)
#ax2.add_artist(legend1)
#L.get_texts()[0].set_text("Touch at: {:.2f}s,{:.2f}mm".format(time1[3219],hall1[3219]))
#L.get_texts()[1].set_text("Force peak: {:.2f} N".format(y2))
#L.get_texts()[2].set_text("Force peak: {:.2f} N".format(y3))
#L.get_texts()[3].set_text("Force peak: {:.2f} N".format(y4))
#L.get_texts()[4].set_text("Force peak: {:.2f} N".format(y5))
image_path = "/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/setup.jpg"
image = imread(image_path)
ax3.axis('off')
ax3.imshow(image)
plt.show()

# %%
print(time5[2700+55:].size)
print(time5[-1:]-time5[2700+55:])
# Out:
# 548
# [1.09333737 1.09133858 1.08933979 1.08734101 1.08534222 1.08334343
#  1.08134464 1.07934585 1.07734706 1.07534827 1.07334949 1.0713507
#  1.06935191 1.06735312 1.06535433 1.06335554 1.06135675 1.05935796
#  1.05735918 1.05536039 1.0533616  1.05136281 1.04936402 1.04736523
#  1.04536644 1.04336766 1.04136887 1.03937008 1.03737129 1.0353725
#  1.03337371 1.03137492 1.02937614 1.02737735 1.02537856 1.02337977
#  1.02138098 1.01938219 1.0173834  1.01538462 1.01338583 1.01138704
#  1.00938825 1.00738946 1.00539067 1.00339188 1.0013931  0.99939431
#  0.99739552 0.99539673 0.99339794 0.99139915 0.98940036 0.98740157
#  0.98540279 0.983404   0.98140521 0.97940642 0.97740763 0.97540884
#  0.97341005 0.97141127 0.96941248 0.96741369 0.9654149  0.96341611
#  0.96141732 0.95941853 0.95741975 0.95542096 0.95342217 0.95142338
#  0.94942459 0.9474258  0.94542701 0.94342823 0.94142944 0.93943065
#  0.93743186 0.93543307 0.93343428 0.93143549 0.92943671 0.92743792
# ...

# %%
#from below
'''
force = -df_fd["fz"]
#acc1 = -df1["ax"]
ax4.scatter( 29.5, 0.75,color = 'r',marker='x', s = 15)
ax4.scatter(35,1.45, color = 'r',marker='x', s = 15)
ax4.scatter( 29.5,2.51,color = 'r',marker='x', s = 15)
ax4.scatter(20.8,4.0, color = 'r',marker='x', s = 15)
ax4.scatter(17,5.5, color = 'r',marker='x', s = 15)
ax4.axhline(y = 0.75,xmin=0.0, xmax=0.47, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 1.45,xmin=0.0, xmax=0.55, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 2.51,xmin=0.0, xmax=0.47, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 4.0,xmin=0.0, xmax=0.35, color = 'g', linestyle = '--',linewidth=1.0)
ax4.axhline(y = 5.5,xmin=0.0, xmax=0.28, color = 'g', linestyle = '--',linewidth=1.0)
ax4.text(29.5+1, 0.75-0.1, 'k1', size = 10)
ax4.text( 35+1,1.45-0.1, 'k2', size = 10)
ax4.text( 29.5+1, 2.51-0.1,'k3', size = 10)
ax4.text( 20.8+1,4.0-0.1, 'k4', size = 10)
ax4.text( 17+1,5.5-0.1, 'k5', size = 10)
ax4.plot(force[3200:],x[3200:],linewidth=1.0)



major_ticksx4 = np.arange(0, 70, 5)
major_ticksy4 = np.arange(-0.5, 7.5, 0.5)
ax4.set_xticks(major_ticksx4)
ax4.set_yticks(major_ticksy4)
ax4.tick_params(axis='both', which='major', labelsize=10)
ax4.grid(linestyle='dashed', alpha = 0.3)
ax4.set_ylabel('Hall Displacement, mm',fontsize = 15)
ax4.set_xlabel('Force, N',fontsize = 15)
#ax2.add_artist(legend1)
#L.get_texts()[0].set_text("Touch at: {:.2f}s,{:.2f}mm".format(time1[3219],hall1[3219]))
#L.get_texts()[1].set_text("Force peak: {:.2f} N".format(y2))
#L.get_texts()[2].set_text("Force peak: {:.2f} N".format(y3))
#L.get_texts()[3].set_text("Force peak: {:.2f} N".format(y4))
#L.get_texts()[4].set_text("Force peak: {:.2f} N".format(y5))
image_path = "/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/setup.jpg"
image = imread(image_path)
ax3.axis('off')
ax3.imshow(image)
'''

# %%
from matplotlib.image import imread
from matplotlib.lines import Line2D
fig, axs = plt.subplots(2,figsize=(12,8), dpi= 150, facecolor='w', edgecolor='k')
ax1 = axs[0]
ax2 = axs[1]
#ax3 = axs[0,1]
#ax4 = axs[1,1]
x1 = force1.idxmax()
x2 = force2.idxmax()
x3 = force3.idxmax()
x4 = force4.idxmax()
x5 = force5.idxmax()


ax1.plot(time1[0:force1.size-1400], force1[1400:], alpha=0.5,linewidth=2.0)
ax1.plot(time2[0:force2.size-2000], force2[2000:], alpha=0.5,linewidth=2.0)
ax1.plot(time3[0:force3.size-1600], force3[1600:], alpha=0.5,linewidth=2.0)
ax1.plot(time4[0:force4.size-1300], force4[1300:], alpha=0.5,linewidth=2.0)
ax1.plot(time5[0:force5.size-2000], force5[2000:], alpha=0.5,linewidth=2.0)

major_ticksx1 = np.arange(0,6.5,1)
#ax1.set_xlim(4, 9.5)
#ax2.set_xlim(4, 9.5)
major_ticksy1 = np.arange(0, 20, 5)
ax1.set_xticks(major_ticksx1)
ax1.set_yticks(major_ticksy1)
ax1.tick_params(axis='x', which='major', labelsize=30,labelbottom=False)
ax1.tick_params(axis='y', which='major', labelsize=30)
ax1.grid(linestyle='dashed', alpha = 0.3)
#ax1.set_xlabel('time, s',fontsize = 25)
ax1.set_ylabel('Force, N',fontsize = 30)

ax1.scatter(time1[x1-1400], y1, s = 12)
ax1.text(time1[x1-1400], y1, '{:.2f}N'.format(y1), size = 15,weight='bold')
ax1.scatter(time2[x2-2000], y2, s = 12)
ax1.text(time2[x2-2000], y2, '{:.2f}N'.format(y2), size = 15,weight='bold')
ax1.scatter(time3[x3-1600], y3, s = 12)
ax1.text(time3[x3-1600], y3, '{:.2f}N'.format(y3), size = 15,weight='bold')
ax1.scatter(time4[x4-1300], y4, s = 12)
ax1.text(time4[x4-1300], y4, '{:.2f}N'.format(y4), size = 15,weight='bold')
ax1.scatter(time5[x5-2000], y5, s = 12)
ax1.text(time5[x5-2000], y5, '{:.2f}N'.format(y5), size = 15,weight='bold')

ax1.scatter(time1[3219-1400], force1[3219],c='b', s = 80,marker='x',linewidth=3)
ax1.text(time1[3219-1400]-0.55, force1[3219], '{:.2f}N'.format(force1[3219]), size = 15,weight='bold')
ax1.scatter(time2[3484-2000], force2[3484],c = 'orange', s = 80,marker='x',linewidth=3)
ax1.text(time2[3484-2000]-0.55, force2[3484], '{:.2f}N'.format(force2[3484]), size = 15,weight='bold')
ax1.scatter(time3[3789-1600], force3[3789], c = 'g', s = 80,marker='x',linewidth=3)
ax1.text(time3[3789-1600]-0.48, force3[3789], '{:.2f}N'.format(force3[3789]), size = 15,weight='bold')
ax1.scatter(time4[2671-1300], force4[2671], c = 'r', s = 80,marker='x',linewidth=3)
ax1.text(time4[2671-1300]-0.48, force4[2671], '{:.2f}N'.format(force4[2671]), size = 15,weight='bold')
ax1.scatter(time5[2803-2000], force5[2803], c = 'purple', s = 80,marker='x',linewidth=3)
ax1.text(time5[2803-2000]-0.48, force5[2803], '{:.2f}N'.format(force5[2803]), size = 15,weight='bold')
#ax1.axvline(x = time1[3219], color = 'b', linestyle = '-',ymin=0.0, ymax=0.80,linewidth=1.0)
#ax1.axvline(x = time2[3484], color = 'orange', linestyle = '-',ymin=0.0, ymax=0.70,linewidth=1.0)
#ax1.axvline(x = time3[3789], color = 'g', linestyle = '-',ymin=0.0, ymax=0.47,linewidth=1.0)
#ax1.axvline(x = time4[2671], color = 'r', linestyle = '-',ymin=0.0, ymax=0.47,linewidth=1.0)
#ax1.axvline(x = time5[2803], color = 'purple', linestyle = '-',ymin=0.0, ymax=0.47,linewidth=1.0)



#ax2 = fig.add_subplot(1, 1, 1)
ax2.plot(time1[1:hall1.size-1400], hall1[1401:], alpha=0.7,linewidth=2.0)
ax2.plot(time2[1:force2.size-2000], hall2[2001:], alpha=0.7,linewidth=2.0)
ax2.plot(time3[1:force3.size-1600], hall3[1601:], alpha=0.7,linewidth=2.0)
ax2.plot(time4[1:force4.size-1300], hall4[1301:], alpha=0.7,linewidth=2.0)
ax2.plot(time5[1:force5.size-2000], hall5[2001:], alpha=0.7,linewidth=2.0)
scat1 = ax2.scatter(time1[3219-1400],hall1[3219], s = 80,alpha=1,marker='x',linewidth=3)
scat2 = ax2.scatter(time2[3484-2000],hall2[3484],  s = 80,alpha=1,marker='x',linewidth=3)
scat3 = ax2.scatter(time3[3789-1600],hall3[3789],  s = 80,alpha=1,marker='x',linewidth=3)
scat4 = ax2.scatter(time4[2671-1300],hall4[2671],  s = 80,alpha=1,marker='x',linewidth=3)
scat5 = ax2.scatter(time5[2803-2000],hall5[2803],  s = 80,alpha=1,marker='x',linewidth=3)
legend_elements = [Line2D([0], [0], marker='x', color='b', label='Mode 1',markerfacecolor='b', markersize=10),
                   Line2D([0], [0], marker='x', color='orange', label='Mode 2',markerfacecolor='orange', markersize=10),
                   Line2D([0], [0], marker='x', color='g', label='Mode 3',markerfacecolor='g', markersize=10),
                   Line2D([0], [0], marker='x', color='r', label='Mode 4',markerfacecolor='r', markersize=10),
                   Line2D([0], [0], marker='x', color='purple', label='Mode 5',markerfacecolor='purple', markersize=10),]




major_ticksx2 = np.arange(0,5.5,1)
major_ticksy2 = np.arange(0.0, 8, 2.0)
ax2.set_xticks(major_ticksx2)
ax2.set_yticks(major_ticksy2)
ax2.tick_params(axis='x', which='major', labelsize=30)
ax2.tick_params(axis='y', which='major', labelsize=30)
ax2.grid(linestyle='dashed', alpha = 0.3)
ax2.set_xlabel('Time, s',fontsize = 30)
ax2.set_ylabel(u'ΔD, mm',fontsize = 30)

#L = ax2.legend(loc=1, prop={'size': 10},handles=[scat1, scat2,scat3,scat4,scat5])



#legend1 = fig.legend(handles=legend_elements, loc="best", prop={'size': 10},borderaxespad=0)
#legend1.set_title('Touch Detection',prop={'size':10})




plt.savefig('/home/rustam/catkin_ws/src/calibrate_rgb_sensor_rustam/src/new setup/light touch/continuous/all_trials_without_legend.eps', format='eps')
#plt.show()

# %%
norm_force1 = pd.DataFrame(force1[3100+18:].values)
norm_force2 = pd.DataFrame(force2[3100+18:].values)
norm_force3 = pd.DataFrame(force3[3100+18:].values)
norm_force4 = pd.DataFrame(force4[3100+18:].values)
norm_force5 = pd.DataFrame(force5[3100+18:].values)
norm_force1.columns = range(len(norm_force1.columns))

x1_1 = norm_force1.idxmax()

#x1_1 = force1[3100+18:].idxmax()
#time1[x1_1]
x1_1
# Out:
# 0    121
# dtype: int64

# %% [markdown]
# # All trials with new x-axis

# %%
fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(1, 1, 1)


x1_1 = np.linspace(0,1.147,603-25)
x2_1 = np.linspace(2,2.82,603-25)
x3_1 = np.linspace(4,5+0.097,603-55)
x4_1 = np.linspace(6,7+0.097,603-50)
x5_1 = np.linspace(8,9+0.093,603-55)

ax.scatter(x1_1, force1[3100+18+25:]-0.3, alpha=1,s = 15,marker='.')
ax.scatter(x2_1, force2[3350+31+25:]-0.3, alpha=1,s = 15,marker='.')
ax.scatter(x3_1, force3[3700-14+55:], alpha=1,s = 15,marker='.')
ax.scatter(x4_1, force4[2500+68+50:], alpha=1,s = 15,marker='.')
ax.scatter(x5_1, force5[2700+55:], alpha=1,s = 15,marker='.')




norm_force1 = pd.DataFrame(force1[3100+18:].values)
norm_force2 = pd.DataFrame(force2[3350+31:].values)
norm_force3 = pd.DataFrame(force3[3700-14:].values)
norm_force4 = pd.DataFrame(force4[2500+68:].values)
norm_force5 = pd.DataFrame(force5[2700:].values)
norm_force1.columns = range(len(norm_force1.columns))
norm_force2.columns = range(len(norm_force2.columns))
norm_force3.columns = range(len(norm_force3.columns))
norm_force4.columns = range(len(norm_force4.columns))
norm_force5.columns = range(len(norm_force5.columns))
x1_1_id = norm_force1.idxmax()
x2_1_id = norm_force2.idxmax()
x3_1_id = norm_force3.idxmax()
x4_1_id = norm_force4.idxmax()
x5_1_id = norm_force5.idxmax()


ax.scatter(x1_1[x1_1_id-25], y1-0.3, s = 20,c='b',edgecolors='black')
ax.text(x1_1[x1_1_id-590], y1, '{:.2f}N'.format(y1), size = 15,weight='bold')

ax.scatter(x2_1[x2_1_id-25], y2-0.3, s = 20,c = 'darkorange',edgecolors='black')
ax.text(x2_1[x2_1_id-590], y2, '{:.2f}N'.format(y2), size = 15,weight='bold')

ax.scatter(x3_1[x3_1_id-55], y3, s = 20, c = 'g',edgecolors='black')
ax.text(x3_1[x3_1_id-590], y3, '{:.2f}N'.format(y3), size = 15,weight='bold')

ax.scatter(x4_1[x4_1_id-50], y4, s = 20, c = 'r',edgecolors='black')
ax.text(x4_1[x4_1_id-590], y4, '{:.2f}N'.format(y4), size = 15,weight='bold')

ax.scatter(x5_1[x5_1_id-55], y5, s = 20, c = 'purple',edgecolors='black')
ax.text(x5_1[x5_1_id-590], y5, '{:.2f}N'.format(y5), size = 15,weight='bold')

#------------

ax.scatter(x1_1[x1_1_id-20-25], force1[3219]-0.3,c='b',edgecolors='black', s = 30,marker='X',linewidth=1)
ax.text(x1_1[x1_1_id], force1[3214], '{:.2f}N'.format(force1[3219]), size = 15,weight='bold')

ax.scatter(x2_1[x2_1_id-18-25], force2[3484]-0.3,c = 'darkorange', s = 30,marker='X',linewidth=1,edgecolors='black')
ax.text(x2_1[x2_1_id], force2[3475], '{:.2f}N'.format(force2[3484]), size = 15,weight='bold')

ax.scatter(x3_1[x3_1_id-20-55], force3[3789], c = 'g', s = 30,marker='X',linewidth=1,edgecolors='black')
ax.text(x3_1[x3_1_id-20]-1, force3[3789], '{:.2f}N'.format(force3[3789]), size = 15,weight='bold')

ax.scatter(x4_1[x4_1_id-20-50], force4[2671], c = 'r', s = 30,marker='X',linewidth=1,edgecolors='black')
ax.text(x4_1[x4_1_id]-0.9, force4[2665], '{:.2f}N'.format(force4[2671]), size = 15,weight='bold')

ax.scatter(x5_1[x5_1_id-20-55], force5[2803], c = 'purple', s = 30,marker='X',linewidth=1,edgecolors='black')
ax.text(x5_1[x5_1_id]-1.0, force5[2803], '{:.2f}N'.format(force5[2803]), size = 15,weight='bold')


major_ticksx = [0,2,4,6,8,10]
states = ['state 1', 'state 2', 'state 3', 'state 4', 'state 5']
major_ticksy = np.arange(0, 20, 5)
ax.set_xticks(major_ticksx)
ax.set_xticklabels(states, minor=False)
ax.set_yticks(major_ticksy)
ax.tick_params(axis='x', which='major', labelsize=30)
ax.tick_params(axis='y', which='major', labelsize=30)
ax.grid(linestyle='dashed', alpha = 0.3)
ax.set_ylabel('Force, N',fontsize = 30)
# Out:
# Text(0,0.5,'Force, N')

# %%
fig=plt.figure(figsize=(12,8), dpi= 300, facecolor='w', edgecolor='k')
ax = fig.add_subplot(1, 1, 1)


x1_1 = np.linspace(0,2,603-20)
x2_1 = np.linspace(0,2,603-20)
x3_1 = np.linspace(0,2,603-50)
x4_1 = np.linspace(0,2,603-46)
x5_1 = np.linspace(0,2,553)

ax.plot(x1_1, force1[3100+18+20:]-0.3, alpha=0.5,linewidth=2.0)
ax.plot(x2_1, force2[3350+31+20:]-0.3, alpha=0.5,linewidth=2.0)
ax.plot(x3_1, force3[3700-14+50:], alpha=0.5,linewidth=2.0)
ax.plot(x4_1, force4[2500+68+46:], alpha=0.5,linewidth=2.0)
ax.plot(x5_1, force5[2700+50:], alpha=0.5,linewidth=2.0)

#major_ticksx1 = np.arange(0,6.5,1)
#ax1.set_xlim(4, 9.5)
#ax2.set_xlim(4, 9.5)
major_ticksy1 = np.arange(0, 20, 5)
#ax.set_xticks(major_ticksx1)
ax.set_yticks(major_ticksy1)
ax.tick_params(axis='x', which='major', labelsize=30)
ax.tick_params(axis='y', which='major', labelsize=30)
ax.grid(linestyle='dashed', alpha = 0.3)
ax.set_xlabel('time, s',fontsize = 25)
ax.set_ylabel('Force, N',fontsize = 30)
# Out:
# Text(0,0.5,'Force, N')
